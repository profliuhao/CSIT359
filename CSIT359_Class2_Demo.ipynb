# %% [markdown]
# <a href="https://colab.research.google.com/github/profliuhao/CSIT359/blob/master/CSIT359_Class2_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
obj = pd.Series(np.arange(4.), index=['a', 'b', 'c', 'd'])
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj['b']
# Out:
# 1.0

# %%
obj[1]
# Out:
# <ipython-input-4-fbfcaec2cced>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   obj[1]
# 1.0

# %%
obj[1:3]
# Out:
# b    1.0
# c    2.0
# dtype: float64

# %%
obj['b':'d']
# Out:
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj[['b', 'a', 'd']]
# Out:
# b    1.0
# a    0.0
# d    3.0
# dtype: float64

# %%
obj[[1, 3]]
# Out:
# <ipython-input-8-d1c6085fe620>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   obj[[1, 3]]
# b    1.0
# d    3.0
# dtype: float64

# %%
obj[obj < 2]
# Out:
# a    0.0
# b    1.0
# dtype: float64

# %%
obj = pd.Series([1, np.nan, 3, 5, 11, 8, 6])
obj
# Out:
# 0     1.0
# 1     NaN
# 2     3.0
# 3     5.0
# 4    11.0
# 5     8.0
# 6     6.0
# dtype: float64

# %%
obj.sort_index()
# Out:
# 0     1.0
# 1     NaN
# 2     3.0
# 3     5.0
# 4    11.0
# 5     8.0
# 6     6.0
# dtype: float64

# %%
obj.sort_values()
# Out:
# 0     1.0
# 2     3.0
# 3     5.0
# 6     6.0
# 5     8.0
# 4    11.0
# 1     NaN
# dtype: float64

# %%
obj.sort_values(na_position="first")
# Out:
# 1     NaN
# 0     1.0
# 2     3.0
# 3     5.0
# 6     6.0
# 5     8.0
# 4    11.0
# dtype: float64

# %%
frame = pd.DataFrame({"b":[4,7,-3,2], "a": [0,1,0,1]})
frame
# Out:
#    b  a
# 0  4  0
# 1  7  1
# 2 -3  0
# 3  2  1

# %%
frame.sort_values(by='b')
# Out:
#    b  a
# 2 -3  0
# 3  2  1
# 0  4  0
# 1  7  1

# %%
frame.sort_values(by=['a','b'])
# Out:
#    b  a
# 2 -3  0
# 0  4  0
# 3  2  1
# 1  7  1

# %%
frame.sum()
# Out:
# b    10
# a     2
# dtype: int64

# %%
frame.idxmax()
# Out:
# b    1
# a    1
# dtype: int64

# %%
frame.describe()
# Out:
#               b        a
# count  4.000000  4.00000
# mean   2.500000  0.50000
# std    4.203173  0.57735
# min   -3.000000  0.00000
# 25%    0.750000  0.00000
# 50%    3.000000  0.50000
# 75%    4.750000  1.00000
# max    7.000000  1.00000

# %%
obj.value_counts()
# Out:
# 1.0     1
# 3.0     1
# 5.0     1
# 11.0    1
# 8.0     1
# 6.0     1
# Name: count, dtype: int64

# %%
# frame.value_counts(['a'])
frame.a.value_counts()
frame['a'].value_counts()
# Out:
# a
# 0    2
# 1    2
# Name: count, dtype: int64

# %%
data = pd.DataFrame([[1.,6.5,3.0],[1, None, None], [None,None,None], [None, 6.5, 3.]])
data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
cleaned = data.dropna()
cleaned
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
cleaned = data.dropna(how='all')
cleaned
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0
